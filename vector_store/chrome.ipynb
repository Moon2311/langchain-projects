# %%
# !pip install langchain chromadb openai tiktoken pypdf langchain_openai langchain-community
# Out:
# Requirement already satisfied: langchain in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (1.1.2)
# Requirement already satisfied: chromadb in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (1.3.5)
# Requirement already satisfied: openai in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (2.8.1)
# Requirement already satisfied: tiktoken in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (0.12.0)
# Requirement already satisfied: pypdf in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (6.4.0)
# Requirement already satisfied: langchain_openai in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (1.1.0)
# Requirement already satisfied: langchain-community in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (0.4.1)
# Requirement already satisfied: langchain-core<2.0.0,>=1.1.0 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from langchain) (1.1.0)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.2 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from langchain) (1.0.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from langchain) (2.12.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.1.0->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.1.0->langchain) (0.4.49)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.1.0->langchain) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.1.0->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.1.0->langchain) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.1.0->langchain) (4.15.0)
# Requirement already satisfied: jsonpointer>=1.9 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.1.0->langchain) (3.0.0)
# Requirement already satisfied: langgraph-checkpoint<4.0.0,>=2.1.0 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (1.0.5)
# Requirement already satisfied: langgraph-sdk<0.3.0,>=0.2.2 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (0.2.10)
# Requirement already satisfied: xxhash>=3.5.0 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain) (1.12.0)
# Requirement already satisfied: httpx>=0.25.2 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain) (0.25.0)
# Requirement already satisfied: anyio in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (4.12.0)
# Requirement already satisfied: certifi in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (1.0.9)
# Requirement already satisfied: idna in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (3.11)
# Requirement already satisfied: h11>=0.16 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: build>=1.0.3 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from chromadb) (1.3.0)
# Requirement already satisfied: pybase64>=1.4.1 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from chromadb) (1.4.3)
# Requirement already satisfied: uvicorn>=0.18.3 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.38.0)
# Requirement already satisfied: numpy>=1.22.5 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from chromadb) (2.3.5)
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from chromadb) (5.4.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from chromadb) (1.23.2)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from chromadb) (1.39.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from chromadb) (1.39.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from chromadb) (1.39.0)
# Requirement already satisfied: tokenizers>=0.13.2 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from chromadb) (0.20.3)
# Requirement already satisfied: pypika>=0.48.9 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from chromadb) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from chromadb) (1.76.0)
# Requirement already satisfied: bcrypt>=4.0.1 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from chromadb) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from chromadb) (0.20.0)
# Requirement already satisfied: kubernetes>=28.1.0 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from chromadb) (34.1.0)
# Requirement already satisfied: mmh3>=4.0.1 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from chromadb) (5.2.0)
# Requirement already satisfied: rich>=10.11.0 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from chromadb) (14.2.0)
# Requirement already satisfied: jsonschema>=4.19.0 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from chromadb) (4.25.1)
# Requirement already satisfied: six>=1.5 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.2 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: backoff>=1.10.0 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.9.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain) (2.3.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from openai) (0.12.0)
# Requirement already satisfied: sniffio in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from openai) (1.3.1)
# Requirement already satisfied: regex>=2022.1.18 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from tiktoken) (2025.11.3)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from langchain-community) (1.0.0)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from langchain-community) (2.0.44)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from langchain-community) (3.13.2)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from langchain-community) (2.12.0)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.22.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.0.0 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (1.0.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.1)
# Requirement already satisfied: greenlet>=1 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.2.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
# Requirement already satisfied: pyproject_hooks in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from jsonschema>=4.19.0->chromadb) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from jsonschema>=4.19.0->chromadb) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from jsonschema>=4.19.0->chromadb) (0.30.0)
# Requirement already satisfied: google-auth>=1.0.1 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from kubernetes>=28.1.0->chromadb) (2.43.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from kubernetes>=28.1.0->chromadb) (1.9.0)
# Requirement already satisfied: requests-oauthlib in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: durationpy>=0.7 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (6.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from rsa<5,>=3.1.4->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.1)
# Requirement already satisfied: coloredlogs in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from onnxruntime>=1.14.1->chromadb) (25.9.23)
# Requirement already satisfied: protobuf in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from onnxruntime>=1.14.1->chromadb) (6.33.2)
# Requirement already satisfied: sympy in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from onnxruntime>=1.14.1->chromadb) (1.14.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.23.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.72.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.39.0 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.39.0)
# Requirement already satisfied: opentelemetry-proto==1.39.0 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.39.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.60b0 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.60b0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from rich>=10.11.0->chromadb) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from rich>=10.11.0->chromadb) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from tokenizers>=0.13.2->chromadb) (0.36.0)
# Requirement already satisfied: filelock in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2025.10.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (1.2.0)
# Requirement already satisfied: click>=8.0.0 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from typer>=0.9.0->chromadb) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.7.1)
# Requirement already satisfied: uvloop>=0.15.1 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.22.1)
# Requirement already satisfied: watchfiles>=0.13 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (15.0.1)
# Requirement already satisfied: humanfriendly>=9.1 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)

# %%
# !pip install chromadb
# Out:
# Requirement already satisfied: chromadb in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (1.3.5)
# Requirement already satisfied: build>=1.0.3 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from chromadb) (1.3.0)
# Requirement already satisfied: pydantic>=1.9 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from chromadb) (2.12.5)
# Requirement already satisfied: pybase64>=1.4.1 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from chromadb) (1.4.3)
# Requirement already satisfied: uvicorn>=0.18.3 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.38.0)
# Requirement already satisfied: numpy>=1.22.5 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from chromadb) (2.3.5)
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from chromadb) (5.4.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from chromadb) (4.15.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from chromadb) (1.23.2)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from chromadb) (1.39.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from chromadb) (1.39.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from chromadb) (1.39.0)
# Requirement already satisfied: tokenizers>=0.13.2 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from chromadb) (0.20.3)
# Requirement already satisfied: pypika>=0.48.9 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from chromadb) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from chromadb) (1.76.0)
# Requirement already satisfied: bcrypt>=4.0.1 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from chromadb) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from chromadb) (0.20.0)
# Requirement already satisfied: kubernetes>=28.1.0 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from chromadb) (34.1.0)
# Requirement already satisfied: tenacity>=8.2.3 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from chromadb) (9.1.2)
# Requirement already satisfied: pyyaml>=6.0.0 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from chromadb) (6.0.3)
# Requirement already satisfied: mmh3>=4.0.1 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from chromadb) (5.2.0)
# Requirement already satisfied: orjson>=3.9.12 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from chromadb) (3.11.4)
# Requirement already satisfied: httpx>=0.27.0 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from chromadb) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from chromadb) (14.2.0)
# Requirement already satisfied: jsonschema>=4.19.0 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from chromadb) (4.25.1)
# Requirement already satisfied: requests<3.0,>=2.7 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.32.5)
# Requirement already satisfied: six>=1.5 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.2 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: backoff>=1.10.0 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.9.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (2025.11.12)
# Requirement already satisfied: packaging>=19.1 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from build>=1.0.3->chromadb) (25.0)
# Requirement already satisfied: pyproject_hooks in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: anyio in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from httpx>=0.27.0->chromadb) (4.12.0)
# Requirement already satisfied: httpcore==1.* in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from httpx>=0.27.0->chromadb) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from jsonschema>=4.19.0->chromadb) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from jsonschema>=4.19.0->chromadb) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from jsonschema>=4.19.0->chromadb) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from jsonschema>=4.19.0->chromadb) (0.30.0)
# Requirement already satisfied: google-auth>=1.0.1 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from kubernetes>=28.1.0->chromadb) (2.43.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from kubernetes>=28.1.0->chromadb) (1.9.0)
# Requirement already satisfied: requests-oauthlib in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: durationpy>=0.7 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (6.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from rsa<5,>=3.1.4->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.1)
# Requirement already satisfied: coloredlogs in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from onnxruntime>=1.14.1->chromadb) (25.9.23)
# Requirement already satisfied: protobuf in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from onnxruntime>=1.14.1->chromadb) (6.33.2)
# Requirement already satisfied: sympy in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from onnxruntime>=1.14.1->chromadb) (1.14.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.23.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.72.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.39.0 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.39.0)
# Requirement already satisfied: opentelemetry-proto==1.39.0 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.39.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.60b0 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.60b0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from pydantic>=1.9->chromadb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from pydantic>=1.9->chromadb) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from pydantic>=1.9->chromadb) (0.4.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from rich>=10.11.0->chromadb) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from rich>=10.11.0->chromadb) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from tokenizers>=0.13.2->chromadb) (0.36.0)
# Requirement already satisfied: filelock in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2025.10.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (1.2.0)
# Requirement already satisfied: click>=8.0.0 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from typer>=0.9.0->chromadb) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.7.1)
# Requirement already satisfied: python-dotenv>=0.13 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.2.1)
# Requirement already satisfied: uvloop>=0.15.1 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.22.1)
# Requirement already satisfied: watchfiles>=0.13 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (15.0.1)
# Requirement already satisfied: humanfriendly>=9.1 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)

# %%
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_openai import OpenAIEmbeddings

from langchain_chroma import Chroma

embedding_model = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 2
#       1 from langchain_openai import OpenAIEmbeddings
# ----> 2 from langchain.vectorstores import Chroma
#
# ModuleNotFoundError: No module named 'langchain.vectorstores'

# %%
from langchain_core.documents import Document


# Create LangChain documents for IPL players

doc1 = Document(
        page_content="Virat Kohli is one of the most successful and consistent batsmen in IPL history. Known for his aggressive batting style and fitness, he has led the Royal Challengers Bangalore in multiple seasons.",
        metadata={"team": "Royal Challengers Bangalore"}
    )
doc2 = Document(
        page_content="Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure.",
        metadata={"team": "Mumbai Indians"}
    )
doc3 = Document(
        page_content="MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.",
        metadata={"team": "Chennai Super Kings"}
    )
doc4 = Document(
        page_content="Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.",
        metadata={"team": "Mumbai Indians"}
    )
doc5 = Document(
        page_content="Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.",
        metadata={"team": "Chennai Super Kings"}
    )

# %%
docs = [doc1, doc2, doc3, doc4, doc5]

# %%
from langchain_chroma import Chroma

from langchain_huggingface import HuggingFaceEmbeddings
from langchain_openai import OpenAIEmbeddings
from langchain_core.documents import Document
from langchain_chroma import Chroma

embedding_model = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)




# Create LangChain documents for IPL players

doc1 = Document(
        page_content="Virat Kohli is one of the most successful and consistent batsmen in IPL history. Known for his aggressive batting style and fitness, he has led the Royal Challengers Bangalore in multiple seasons.",
        metadata={"team": "Royal Challengers Bangalore"}
    )
doc2 = Document(
        page_content="Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure.",
        metadata={"team": "Mumbai Indians"}
    )
doc3 = Document(
        page_content="MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.",
        metadata={"team": "Chennai Super Kings"}
    )
doc4 = Document(
        page_content="Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.",
        metadata={"team": "Mumbai Indians"}
    )
doc5 = Document(
        page_content="Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.",
        metadata={"team": "Chennai Super Kings"}
    )

vector_store = Chroma(
    embedding_function=embedding_model,
    persist_directory='my_chroma_db',
    collection_name='sample'
)
# Out:
# /home/talha/code/langchain projects/.venv/lib/python3.13/site-packages/transformers/tokenization_utils_base.py:1617: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be deprecated in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
# add documents
vector_store.add_documents(docs)
# Out:
# ['c9be3af9-34fc-419b-aed9-d7225acf71bb',
#  'a9d1ab87-403e-4453-a703-332006b07060',
#  '843a85db-4142-4ac4-b637-1d4270a5daf8',
#  'ead1e8ec-ed7b-4199-a5df-4ee04b1e53d9',
#  '78ccc8fd-daa5-4e72-9795-a35fd67960d9']

# %%
# view documents
vector_store.get(include=['embeddings','documents', 'metadatas'])
# Out:
# {'ids': ['c9be3af9-34fc-419b-aed9-d7225acf71bb',
#   'a9d1ab87-403e-4453-a703-332006b07060',
#   '843a85db-4142-4ac4-b637-1d4270a5daf8',
#   'ead1e8ec-ed7b-4199-a5df-4ee04b1e53d9',
#   '78ccc8fd-daa5-4e72-9795-a35fd67960d9'],
#  'embeddings': array([[ 0.00994727,  0.06914338, -0.05147114, ..., -0.03543339,
#           0.01284807,  0.01248292],
#         [ 0.00127746,  0.03129854, -0.02375373, ..., -0.00518361,
#          -0.03280614,  0.02737715],
#         [-0.10265917,  0.02650814,  0.02271501, ..., -0.03359744,
#          -0.07984947, -0.01507708],
#         [ 0.02123394, -0.02468546, -0.04494374, ..., -0.10995816,
#           0.00572557,  0.09915376],
#         [ 0.0187398 ,  0.04382848, -0.04304254, ..., -0.07801622,
#          -0.07840682, -0.00304187]], shape=(5, 384)),
#  'documents': ['Virat Kohli is one of the most successful and consistent batsmen in IPL history. Known for his aggressive batting style and fitness, he has led the Royal Challengers Bangalore in multiple seasons.',
#   "Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure.",
#   'MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.',
#   'Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.',
#   'Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.'],
#  'uris': None,
#  'included': ['embeddings', 'documents', 'metadatas'],
#  'data': None,
#  'metadatas': [{'team': 'Royal Challengers Bangalore'},
#   {'team': 'Mumbai Indians'},
#   {'team': 'Chennai Super Kings'},
#   {'team': 'Mumbai Indians'},
#   {'team': 'Chennai Super Kings'}]}

# %%
# search documents
vector_store.similarity_search(
    query='Who among these are a bowler?',
    k=2
)
# Out:
# [Document(id='ead1e8ec-ed7b-4199-a5df-4ee04b1e53d9', metadata={'team': 'Mumbai Indians'}, page_content='Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.'),
#  Document(id='a9d1ab87-403e-4453-a703-332006b07060', metadata={'team': 'Mumbai Indians'}, page_content="Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure.")]

# %%
# search with similarity score
vector_store.similarity_search_with_score(
    query='Who among these are a bowler?',
    k=2
)
# Out:
# [(Document(id='ead1e8ec-ed7b-4199-a5df-4ee04b1e53d9', metadata={'team': 'Mumbai Indians'}, page_content='Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.'),
#   0.9693599939346313),
#  (Document(id='a9d1ab87-403e-4453-a703-332006b07060', metadata={'team': 'Mumbai Indians'}, page_content="Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure."),
#   1.1493449211120605)]

# %%
# meta-data filtering
vector_store.similarity_search_with_score(
    query="",
    filter={"team": "Chennai Super Kings"}
)
# Out:
# [(Document(id='843a85db-4142-4ac4-b637-1d4270a5daf8', metadata={'team': 'Chennai Super Kings'}, page_content='MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.'),
#   1.8436002731323242),
#  (Document(id='78ccc8fd-daa5-4e72-9795-a35fd67960d9', metadata={'team': 'Chennai Super Kings'}, page_content='Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.'),
#   1.890937328338623)]

# %%
# update documents
updated_doc1 = Document(
    page_content="Virat Kohli, the former captain of Royal Challengers Bangalore (RCB), is renowned for his aggressive leadership and consistent batting performances. He holds the record for the most runs in IPL history, including multiple centuries in a single season. Despite RCB not winning an IPL title under his captaincy, Kohli's passion and fitness set a benchmark for the league. His ability to chase targets and anchor innings has made him one of the most dependable players in T20 cricket.",
    metadata={"team": "Royal Challengers Bangalore"}
)

vector_store.update_document(document_id='c9be3af9-34fc-419b-aed9-d7225acf71bb', document=updated_doc1)

# %%
# view documents
vector_store.get(include=['embeddings','documents', 'metadatas'])
# Out:
# {'ids': ['c9be3af9-34fc-419b-aed9-d7225acf71bb',
#   'a9d1ab87-403e-4453-a703-332006b07060',
#   '843a85db-4142-4ac4-b637-1d4270a5daf8',
#   'ead1e8ec-ed7b-4199-a5df-4ee04b1e53d9',
#   '78ccc8fd-daa5-4e72-9795-a35fd67960d9'],
#  'embeddings': array([[-0.00233747,  0.05902085, -0.04774045, ..., -0.07264047,
#           0.00276782, -0.00344085],
#         [ 0.00127746,  0.03129854, -0.02375373, ..., -0.00518361,
#          -0.03280614,  0.02737715],
#         [-0.10265917,  0.02650814,  0.02271501, ..., -0.03359744,
#          -0.07984947, -0.01507708],
#         [ 0.02123394, -0.02468546, -0.04494374, ..., -0.10995816,
#           0.00572557,  0.09915376],
#         [ 0.0187398 ,  0.04382848, -0.04304254, ..., -0.07801622,
#          -0.07840682, -0.00304187]], shape=(5, 384)),
#  'documents': ["Virat Kohli, the former captain of Royal Challengers Bangalore (RCB), is renowned for his aggressive leadership and consistent batting performances. He holds the record for the most runs in IPL history, including multiple centuries in a single season. Despite RCB not winning an IPL title under his captaincy, Kohli's passion and fitness set a benchmark for the league. His ability to chase targets and anchor innings has made him one of the most dependable players in T20 cricket.",
#   "Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure.",
#   'MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.',
#   'Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.',
#   'Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.'],
#  'uris': None,
#  'included': ['embeddings', 'documents', 'metadatas'],
#  'data': None,
#  'metadatas': [{'team': 'Royal Challengers Bangalore'},
#   {'team': 'Mumbai Indians'},
#   {'team': 'Chennai Super Kings'},
#   {'team': 'Mumbai Indians'},
#   {'team': 'Chennai Super Kings'}]}

# %%
# delete document
vector_store.delete(ids=['78ccc8fd-daa5-4e72-9795-a35fd67960d9'])

# %%
# view documents
vector_store.get(include=['embeddings','documents', 'metadatas'])
# Out:
# {'ids': ['c9be3af9-34fc-419b-aed9-d7225acf71bb',
#   'a9d1ab87-403e-4453-a703-332006b07060',
#   '843a85db-4142-4ac4-b637-1d4270a5daf8',
#   'ead1e8ec-ed7b-4199-a5df-4ee04b1e53d9'],
#  'embeddings': array([[-0.00233747,  0.05902085, -0.04774045, ..., -0.07264047,
#           0.00276782, -0.00344085],
#         [ 0.00127746,  0.03129854, -0.02375373, ..., -0.00518361,
#          -0.03280614,  0.02737715],
#         [-0.10265917,  0.02650814,  0.02271501, ..., -0.03359744,
#          -0.07984947, -0.01507708],
#         [ 0.02123394, -0.02468546, -0.04494374, ..., -0.10995816,
#           0.00572557,  0.09915376]], shape=(4, 384)),
#  'documents': ["Virat Kohli, the former captain of Royal Challengers Bangalore (RCB), is renowned for his aggressive leadership and consistent batting performances. He holds the record for the most runs in IPL history, including multiple centuries in a single season. Despite RCB not winning an IPL title under his captaincy, Kohli's passion and fitness set a benchmark for the league. His ability to chase targets and anchor innings has made him one of the most dependable players in T20 cricket.",
#   "Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure.",
#   'MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.',
#   'Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.'],
#  'uris': None,
#  'included': ['embeddings', 'documents', 'metadatas'],
#  'data': None,
#  'metadatas': [{'team': 'Royal Challengers Bangalore'},
#   {'team': 'Mumbai Indians'},
#   {'team': 'Chennai Super Kings'},
#   {'team': 'Mumbai Indians'}]}
